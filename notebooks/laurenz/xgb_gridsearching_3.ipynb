# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import holidays
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit, RandomizedSearchCV
from sklearn.metrics import mean_absolute_error, make_scorer

# %% [markdown]
# ## Data Import & Inspection

# %%
# define the data that we want to use

start_date = "2025-02-01 00:00:00"
end_date  = "2026-02-01 00:00:00"
train_date = "2026-01-01"

# %%
#encoded_netgen is already preprocessed using another notebook
weather_df=pd.read_csv("../../raw_data/weather_avg.csv")
generation_df = pd.read_csv("../../raw_data/encoded_netgen.csv")
oilgas_df = pd.read_csv("../../raw_data/oil_gas_prices.csv")
load_df = pd.read_csv("../../raw_data/load_data.csv")
target_df = pd.read_csv("../../raw_data/combined_energy_price_clean.csv", sep='\t')


# electricity price is also preprocessed úsing another notebook
# we just need to remove sequence 1
# sequence 1 is the more correct price to predict
# we decided to use sequence 2 because 15min interval goes further back
target_df = target_df[target_df["Sequence"] != 1]

# oil gas price is daily, also some days are missing due to holiday and weekends
# lets fill missing day values with the price the day before
# then we make it 15-minutes interval but having the same price the whole day

oilgas_df["period"] = pd.to_datetime(oilgas_df["period"])
oilgas_df = oilgas_df.set_index("period").sort_index()

# Create full daily date range
full_range = pd.date_range(start=oilgas_df.index.min(), end=oilgas_df.index.max(), freq="D")

# Reindex to include missing days (weekends/holidays)
oilgas_df = oilgas_df.reindex(full_range)

# Fill missing values with previous day's price
oilgas_df = oilgas_df.ffill()

# Upsample to 15-minute frequency
oilgas_df = oilgas_df.resample("15min").ffill()

oilgas_df = oilgas_df.reset_index()
oilgas_df = oilgas_df.rename(columns={'index': 'DateTime(UTC)'})

# load is raw data obtained from API (Javier)
# the time is in berlin, we will convert it to utc
# we will avaerage out duplicated timesptes
# there are missing values due to end of March

load_df = load_df.rename(columns={"Unnamed: 0": "DateTime(UTC)"})

# Step 1: ensure string and remove last 6 chars
load_df["DateTime(UTC)"] = load_df["DateTime(UTC)"].astype(str).str[:-6]

# Step 2: convert to datetime
load_df["DateTime(UTC)"] = pd.to_datetime(load_df["DateTime(UTC)"], errors="coerce")

# Step 3: subtract 1 hour
# convert to utc
load_df["DateTime(UTC)"] = load_df["DateTime(UTC)"] - pd.Timedelta(hours=1)

# There are duplicated timestep with different valaues, lets take the average for those timesteps
load_df = (
    load_df
    .groupby('DateTime(UTC)', as_index=False)['load']
    .mean()
)

load_df = load_df.set_index('DateTime(UTC)').sort_index()
full_range = pd.date_range(
    start=load_df.index.min(),
    end=load_df.index.max(),
    freq='15min'
)

load_df = load_df.reindex(full_range).ffill()
load_df = load_df.reset_index().rename(columns={'index': 'DateTime(UTC)'})
# Out:
# /var/folders/sj/pc75w_ds6w72_p6qqgqy9m980000gn/T/ipykernel_92744/2526917947.py:6: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   target_df = pd.read_csv("../../raw_data/combined_energy_price_clean.csv", sep='\t')

# %%
oilgas_df.head()
# Out:
#         DateTime(UTC)  WTI_Oil  Brent_Oil  Natural_Gas
# 0 2006-05-16 00:00:00     69.4        NaN          NaN
# 1 2006-05-16 00:15:00     69.4        NaN          NaN
# 2 2006-05-16 00:30:00     69.4        NaN          NaN
# 3 2006-05-16 00:45:00     69.4        NaN          NaN
# 4 2006-05-16 01:00:00     69.4        NaN          NaN

# %%
# Merge and truncate

merged_df = generation_df.merge(
    target_df[["DateTime(UTC)", "Price[Currency/MWh]"]],
    on="DateTime(UTC)",
    how="left"
)

oilgas_df['DateTime(UTC)'] = oilgas_df['DateTime(UTC)'].astype(str)

merged_df = merged_df.merge(
    oilgas_df[["DateTime(UTC)", "WTI_Oil", "Brent_Oil", "Natural_Gas"]],
    on="DateTime(UTC)",
    how="left"
)

load_df['DateTime(UTC)'] = load_df['DateTime(UTC)'].astype(str)

merged_df = merged_df.merge(
    load_df[["DateTime(UTC)", "load"]],
    on="DateTime(UTC)",
    how="left"
)

merged_df["DateTime(UTC)"] = pd.to_datetime(merged_df["DateTime(UTC)"])
merged_df = merged_df.sort_values("DateTime(UTC)")
merged_df = merged_df.set_index("DateTime(UTC)")
merged_df = merged_df.loc[start_date:end_date]
merged_df = merged_df.reset_index()

# %%
def merge_time_series_with_weather(
    main_df,
    weather_df,
    datetime_col="DateTime(UTC)",
    strategy="ffill"  # "ffill" or "interpolate"
    ):
        # -------------------------
    # 1. Convert datetime
    # -------------------------
    main_df = main_df.copy()
    weather_df = weather_df.copy()

    main_df[datetime_col] = pd.to_datetime(main_df[datetime_col])
    weather_df[datetime_col] = pd.to_datetime(weather_df[datetime_col])

    # -------------------------
    # 2. Set index
    # -------------------------
    main_df = main_df.set_index(datetime_col).sort_index()
    weather_df = weather_df.set_index(datetime_col).sort_index()

    # -------------------------
    # 3. Reindex weather to match main timeline
    # -------------------------
    weather_aligned = weather_df.reindex(main_df.index)

    # -------------------------
    # 4. Imputation strategy
    # -------------------------
    if strategy == "ffill":
        weather_aligned = weather_aligned.ffill()

    elif strategy == "interpolate":
        weather_aligned = weather_aligned.interpolate(method="time")

    else:
        raise ValueError("strategy must be either 'ffill' or 'interpolate'")

    # -------------------------
    # 5. Merge
    # -------------------------
    merged = main_df.join(weather_aligned)

    return merged.reset_index()

# %%
model_df = merge_time_series_with_weather(
    merged_df,
    weather_df,
    strategy="ffill"
)

# %% [markdown]
# ## Feature manipulation

# %%
# ---- Basic time features ----
model_df["day_of_week"] = model_df["DateTime(UTC)"].dt.dayofweek
model_df["day_of_year"] = model_df["DateTime(UTC)"].dt.dayofyear
model_df["month"] = model_df["DateTime(UTC)"].dt.month
model_df["year"] = model_df["DateTime(UTC)"].dt.year

# ---- Hour + quarter-hour ----
model_df["hour"] = model_df["DateTime(UTC)"].dt.hour

# quarter of hour: 0,1,2,3
model_df["quarter_hour"] = model_df["DateTime(UTC)"].dt.minute // 15

# ---- German public holidays ----
years = model_df["year"].unique()
de_holidays = holidays.Germany(years=years)

model_df["is_holiday"] = model_df["DateTime(UTC)"].dt.floor("D").isin(de_holidays)

# ---- Bridge day (Brückentag) ----
# A bridge day is typically:
# - Monday before a Tuesday holiday
# - Friday after a Thursday holiday

model_df["date"] = model_df["DateTime(UTC)"].dt.date

holidays_set = set(de_holidays)

def is_bridge_day(date):
    weekday = date.weekday()

    # Monday before Tuesday holiday
    if weekday == 0 and (date + pd.Timedelta(days=1)) in holidays_set:
        return 1

    # Friday after Thursday holiday
    if weekday == 4 and (date - pd.Timedelta(days=1)) in holidays_set:
        return 1

    return 0

model_df["is_bridge_day"] = model_df["date"].apply(is_bridge_day)

# convert holiday boolean to int
model_df["is_holiday"] = model_df["is_holiday"].astype(int)
# Out:
# /var/folders/sj/pc75w_ds6w72_p6qqgqy9m980000gn/T/ipykernel_92744/705250505.py:17: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   model_df["is_holiday"] = model_df["DateTime(UTC)"].dt.floor("D").isin(de_holidays)

# %%
# remove the ordinal features and cyclical encode them
def cyclical_encode(df, col, max_val, offset=0, drop=True):
    sin_col = f"{col}_sin"
    cos_col = f"{col}_cos"

    df[sin_col] = np.sin(2 * np.pi * (df[col] - offset) / max_val)
    df[cos_col] = np.cos(2 * np.pi * (df[col] - offset) / max_val)

    if drop:
        df = df.drop(columns=[col])

    return df

# Apply to your dataframe
model_df = cyclical_encode(model_df, "quarter_hour", 4)
model_df = cyclical_encode(model_df, "hour", 24)
model_df = cyclical_encode(model_df, "day_of_week", 7)
model_df = cyclical_encode(model_df, "day_of_year", 365, offset=1)
model_df = cyclical_encode(model_df, "month", 12, offset=1)

# %%
# Target
# Rolling mean
model_df["price_roll_mean_24"] = model_df["Price[Currency/MWh]"].rolling(24).mean()
model_df["price_roll_mean_96"] = model_df["Price[Currency/MWh]"].rolling(96).mean()
model_df["price_roll_mean_672"] = model_df["Price[Currency/MWh]"].rolling(672).mean()

# Rolling std
model_df["price_roll_std_4"] = model_df["Price[Currency/MWh]"].rolling(4).std()
model_df["price_roll_std_24"] = model_df["Price[Currency/MWh]"].rolling(24).std()
model_df["price_roll_std_96"] = model_df["Price[Currency/MWh]"].rolling(96).std()

model_df["price_lag_1"] = model_df["Price[Currency/MWh]"].shift(1)
model_df["price_lag_4"] = model_df["Price[Currency/MWh]"].shift(4)
model_df["price_lag_12"] = model_df["Price[Currency/MWh]"].shift(12)   # 3 hours
model_df["price_lag_24"] = model_df["Price[Currency/MWh]"].shift(24)   # 6 hours
model_df["price_lag_96"] = model_df["Price[Currency/MWh]"].shift(96)   # 1 day
model_df["price_lag_672"] = model_df["Price[Currency/MWh]"].shift(672) # 1 week

# %%
# generation

model_df["variable_roll_mean_4"] = model_df["variable"].rolling(4).mean()
model_df["variable_roll_mean_24"] = model_df["variable"].rolling(24).mean()
model_df["variable_roll_mean_96"] = model_df["variable"].rolling(96).mean()
model_df["variable_roll_mean_672"] = model_df["variable"].rolling(672).mean()

# Rolling std
model_df["variable_roll_std_4"] = model_df["variable"].rolling(4).std()
model_df["variable_roll_std_24"] = model_df["variable"].rolling(24).std()
model_df["variable_roll_std_96"] = model_df["variable"].rolling(96).std()

model_df["variable_lag_1"] = model_df["variable"].shift(1)
model_df["variable_lag_4"] = model_df["variable"].shift(4)
model_df["variable_lag_12"] = model_df["variable"].shift(12)   # 3 hours
model_df["variable_lag_24"] = model_df["variable"].shift(24)   # 6 hours
model_df["variable_lag_96"] = model_df["variable"].shift(96)   # 1 day
model_df["variable_lag_672"] = model_df["variable"].shift(672) # 1 week

# %%
# let's generate lad and rolling for oil and gas price as well
# only 672 and 1344 rolling are used because oil and gas prices are daily and dont varies much short term
# tested 672 and 1344 rolling are better than just 672 rolling
# so now we have to truncate more data

model_df["wti_roll_mean_672"] = model_df["WTI_Oil"].rolling(672).mean()
model_df["brent_roll_mean_672"] = model_df["Brent_Oil"].rolling(672).mean()
model_df["gas_roll_mean_672"] = model_df["Natural_Gas"].rolling(672).mean()
model_df["wti_roll_mean_1344"] = model_df["WTI_Oil"].rolling(1344).mean()
model_df["brent_roll_mean_1344"] = model_df["Brent_Oil"].rolling(1344).mean()
model_df["gas_roll_mean_1344"] = model_df["Natural_Gas"].rolling(1344).mean()

# Rolling std
model_df["wti_roll_std_672"] = model_df["WTI_Oil"].rolling(672).std()
model_df["brent_roll_std_672"] = model_df["Brent_Oil"].rolling(672).std()
model_df["gas_roll_std_672"] = model_df["Natural_Gas"].rolling(672).std()
model_df["wti_roll_std_1344"] = model_df["WTI_Oil"].rolling(1344).std()
model_df["brent_roll_std_1344"] = model_df["Brent_Oil"].rolling(1344).std()
model_df["gas_roll_std_1344"] = model_df["Natural_Gas"].rolling(1344).std()

# price lag
model_df["wti_lag_672"] = model_df["WTI_Oil"].shift(672)
model_df["brent_lag_672"] = model_df["Brent_Oil"].shift(672)
model_df["gas_lag_672"] = model_df["Natural_Gas"].shift(672)
model_df["wti_lag_1344"] = model_df["WTI_Oil"].shift(1344)
model_df["brent_lag_1344"] = model_df["Brent_Oil"].shift(1344)
model_df["gas_lag_1344"] = model_df["Natural_Gas"].shift(1344)

# %%
model_df["target_288"] = model_df["Price[Currency/MWh]"].shift(-288)
# also add column for known feature of 288 time steps later
model_df['is_holiday_288'] = model_df['is_holiday'].shift(-288)
model_df['is_bridge_day_288'] = model_df['is_bridge_day'].shift(-288)
model_df = model_df.dropna().reset_index(drop=True)

# %%
model_df['temperature_c_288'] = model_df['temperature_c'].shift(-288)
model_df['humidity_percent_288'] = model_df['humidity_percent'].shift(-288)
model_df['cloud_cover_percent_288'] = model_df['cloud_cover_percent'].shift(-288)
model_df['shortwave_radiation_wm2_288'] = model_df['shortwave_radiation_wm2'].shift(-288)
model_df = model_df.dropna().reset_index(drop=True)

# %% [markdown]
# ## Modelling

# %%
start_date = pd.to_datetime(start_date, format="%Y-%m-%d %H:%M:%S")
end_date = pd.to_datetime(end_date, format="%Y-%m-%d %H:%M:%S")

# %%
model_df["DateTime(UTC)"] =  pd.to_datetime(model_df["DateTime(UTC)"], format="%Y-%m-%d %H:%M:%S")

# %%
data_12m = model_df[(model_df["DateTime(UTC)"] >= start_date) & (model_df["DateTime(UTC)"] <= end_date)]

# %%
len(data_12m)
# Out:
# 35041

# %%
data_12m["DateTime(UTC)"].min(), data_12m["DateTime(UTC)"].max()
# Out:
# (Timestamp('2025-02-01 00:00:00'), Timestamp('2026-02-01 00:00:00'))

# %%
data_12m.columns
# Out:
# Index(['DateTime(UTC)', 'other', 'other_renewable', 'stable', 'variable',
#        'Price[Currency/MWh]', 'WTI_Oil', 'Brent_Oil', 'Natural_Gas', 'load',
#        'temperature_c', 'humidity_percent', 'cloud_cover_percent',
#        'shortwave_radiation_wm2', 'year', 'is_holiday', 'date',
#        'is_bridge_day', 'quarter_hour_sin', 'quarter_hour_cos', 'hour_sin',
#        'hour_cos', 'day_of_week_sin', 'day_of_week_cos', 'day_of_year_sin',
#        'day_of_year_cos', 'month_sin', 'month_cos', 'price_roll_mean_24',
#        'price_roll_mean_96', 'price_roll_mean_672', 'price_roll_std_4',
#        'price_roll_std_24', 'price_roll_std_96', 'price_lag_1', 'price_lag_4',
#        'price_lag_12', 'price_lag_24', 'price_lag_96', 'price_lag_672',
#        'variable_roll_mean_4', 'variable_roll_mean_24',
#        'variable_roll_mean_96', 'variable_roll_mean_672',
#        'variable_roll_std_4', 'variable_roll_std_24', 'variable_roll_std_96',
#        'variable_lag_1', 'variable_lag_4', 'variable_lag_12',
#        'variable_lag_24', 'variable_lag_96', 'variable_lag_672',
#        'wti_roll_mean_672', 'brent_roll_mean_672', 'gas_roll_mean_672',
#        'wti_roll_mean_1344', 'brent_roll_mean_1344', 'gas_roll_mean_1344',
#        'wti_roll_std_672', 'brent_roll_std_672', 'gas_roll_std_672',
#        'wti_roll_std_1344', 'brent_roll_std_1344', 'gas_roll_std_1344',
#        'wti_lag_672', 'brent_lag_672', 'gas_lag_672', 'wti_lag_1344',
#        'brent_lag_1344', 'gas_lag_1344', 'target_288', 'is_holiday_288',
#        'is_bridge_day_288', 'temperature_c_288', 'humidity_percent_288',
#        'cloud_cover_percent_288', 'shortwave_radiation_wm2_288'],
#       dtype='object')

# %%
#for running the VM, download data here
#data_12m.to_csv("grid_search.csv")

# %% [markdown]
# ## Grid search

# %%
# ---------------------------
# 1. Prepare data
# ---------------------------


# Define target (3 days ahead = 288 steps)
target = 'target_288'

# Drop non-feature columns
drop_cols = ['DateTime(UTC)',
             'Price[Currency/MWh]',
             target,
             'date']
X = data_12m.drop(columns=drop_cols)
y = data_12m[target]

# ---------------------------
# 2. Time series split
# ---------------------------

tscv = TimeSeriesSplit(n_splits=5)

# ---------------------------
# 3. Define model
# ---------------------------

model = XGBRegressor(
    objective='reg:squarederror',
    tree_method='hist',   # fast for large datasets
    random_state=42
)

# ---------------------------
# 4. Hyperparameter grid
# ---------------------------

param_grid = {
    'n_estimators': [300, 600, 1000],
    'max_depth': [4, 6, 8, 10],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.7, 0.9, 1.0],
    'colsample_bytree': [0.7, 0.9, 1.0],
    'gamma': [0, 0.1, 0.3],
    'reg_alpha': [0, 0.1, 1],
    'reg_lambda': [1, 5, 10]
}

# ---------------------------
# 5. Scoring metric
# ---------------------------

mae_scorer = make_scorer(mean_absolute_error, greater_is_better=False)

# ---------------------------
# 6. Grid Search
# ---------------------------

random_search = RandomizedSearchCV(
    model,
    param_distributions=param_grid,
    n_iter=100,  # try 50–100 first
    scoring=mae_scorer,
    cv=tscv,
    verbose=2,
    n_jobs=-1,
    random_state=42
)

random_search.fit(X, y)

# ---------------------------
# 7. Results
# ---------------------------

print("Best Parameters:")
print(random_search.best_params_)

print("\nBest MAE:")
print(-random_search.best_score_)

# Best model
best_model = random_search.best_estimator_
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=   3.9s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   4.1s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=   4.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=   5.0s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   5.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=   5.7s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   6.0s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   6.8s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   7.4s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=1.0; total time=   7.9s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=1.0; total time=  12.4s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=1.0; total time=  15.1s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=1.0; total time=  18.2s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=1.0; total time=  19.4s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=  34.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.7; total time=  30.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=6, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   3.6s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=6, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   5.1s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=6, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   5.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=6, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   6.3s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=  49.6s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=6, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   6.8s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=  58.5s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.7; total time=  49.3s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time= 1.1min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.7; total time=  59.8s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time= 1.2min
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=  29.1s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  14.9s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.7; total time= 1.2min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.7; total time= 1.3min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=  45.8s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  24.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=  53.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  29.6s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  13.2s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  35.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   9.2s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  18.4s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  21.1s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=  11.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  37.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  23.1s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   5.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=  13.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time= 1.1min
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   8.3s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=  14.4s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=  15.6s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  25.5s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   0.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   9.5s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   1.2s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=  10.4s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   1.5s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=   6.7s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   1.7s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   2.1s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=  11.7s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=   8.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time= 1.2min
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=   9.2s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.05, max_depth=4, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=   2.9s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=  10.2s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.05, max_depth=4, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=   3.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=300, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=   7.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=  11.2s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.05, max_depth=4, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=   4.2s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.05, max_depth=4, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=   5.0s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.05, max_depth=4, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=   5.6s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=300, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=  11.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=300, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=  12.8s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=300, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=  16.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=300, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=  21.7s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  11.2s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.05, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=  20.9s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=   8.3s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  18.9s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.05, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=  29.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=  10.0s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.05, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=  34.4s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  26.0s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=   7.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=  10.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=  11.4s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.05, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=  39.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=  12.5s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  31.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=   9.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=  10.1s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.05, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=  42.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=   7.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=  11.0s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=  12.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  12.1s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  36.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  13.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.7; total time=   5.8s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.7; total time=   7.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  18.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  15.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.7; total time=   8.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  20.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.7; total time=   8.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.7; total time=   9.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=8, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=  11.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  28.8s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=8, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=  15.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=1.0; total time=   9.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  33.2s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=8, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=  18.0s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=8, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=  19.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=1.0; total time=  13.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  39.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=8, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=  20.7s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=1.0; total time=  13.8s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   9.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=1.0; total time=  15.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  43.1s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   7.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=1, reg_lambda=10, subsample=1.0; total time=  16.2s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   8.6s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=  17.0s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=  10.4s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=  11.7s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=  19.9s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=  12.8s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=  21.8s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=  23.3s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=  22.8s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   3.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=  19.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   4.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   4.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=  25.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=  35.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   5.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   6.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=  29.3s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=  42.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=  34.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=  16.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=  37.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=  53.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=  21.4s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=  15.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=  23.7s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=  59.6s
# /Users/laurenzpfleiderer/.pyenv/versions/3.10.6/envs/grid-intelligence/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=  26.3s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   8.9s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=  20.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=  27.9s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   4.7s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=  12.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   5.7s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=  13.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   6.2s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=600, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=   1.6s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=  24.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=600, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=   2.9s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=600, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=   3.8s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   7.5s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=600, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=   4.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   8.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=600, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=   4.4s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=6, n_estimators=600, reg_alpha=0.1, reg_lambda=10, subsample=0.9; total time=   4.0s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=  27.7s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=  15.9s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=6, n_estimators=600, reg_alpha=0.1, reg_lambda=10, subsample=0.9; total time=   4.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=  17.7s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=6, n_estimators=600, reg_alpha=0.1, reg_lambda=10, subsample=0.9; total time=   4.9s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=6, n_estimators=600, reg_alpha=0.1, reg_lambda=10, subsample=0.9; total time=   5.5s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=6, n_estimators=600, reg_alpha=0.1, reg_lambda=10, subsample=0.9; total time=   6.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=  29.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=   7.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=   8.6s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=   6.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=   9.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=   8.6s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=1.0; total time=   4.0s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=   9.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=  12.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=1.0; total time=   4.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=  12.6s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=4, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=4, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=1.0; total time=   5.5s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=  11.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=  11.9s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=4, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=4, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=1.0; total time=   6.0s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=4, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=1.0; total time=   6.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=6, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=0.7; total time=   6.8s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   0.9s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=6, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=0.7; total time=   7.8s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   1.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=6, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=0.7; total time=   8.2s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   1.5s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   1.8s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=4, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=6, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=0.7; total time=   5.5s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   2.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=  16.6s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=4, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   1.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=4, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   1.5s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=6, n_estimators=600, reg_alpha=1, reg_lambda=5, subsample=0.7; total time=   6.7s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=4, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   2.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=4, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   2.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=300, reg_alpha=0.1, reg_lambda=10, subsample=0.9; total time=  29.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=  50.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=300, reg_alpha=0.1, reg_lambda=10, subsample=0.9; total time=   5.0s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=  54.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=300, reg_alpha=0.1, reg_lambda=10, subsample=0.9; total time=   5.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=300, reg_alpha=0.1, reg_lambda=10, subsample=0.9; total time=   3.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=  56.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=300, reg_alpha=0.1, reg_lambda=10, subsample=0.9; total time=   4.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=  58.3s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0.1, reg_lambda=10, subsample=0.9; total time=  45.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   8.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  16.3s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0.1, reg_lambda=10, subsample=0.9; total time=  55.0s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0.1, reg_lambda=10, subsample=0.9; total time= 1.0min
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   8.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  21.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   9.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=  10.6s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  24.7s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0.1, reg_lambda=10, subsample=0.9; total time= 1.1min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  27.0s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   8.4s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0.1, reg_lambda=10, subsample=0.9; total time= 1.2min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  29.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=  12.1s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=  16.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  15.0s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   9.1s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=  22.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  20.1s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=  11.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  22.2s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=  29.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=  13.5s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  24.6s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=  14.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  26.1s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=600, reg_alpha=0.1, reg_lambda=10, subsample=0.7; total time=   4.4s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=  35.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=  11.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=600, reg_alpha=0.1, reg_lambda=10, subsample=0.7; total time=   5.6s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=  15.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=   1.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=  13.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=   1.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=   1.8s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=   1.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=600, reg_alpha=0.1, reg_lambda=10, subsample=0.7; total time=   6.9s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=  16.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=600, reg_alpha=0.1, reg_lambda=10, subsample=0.7; total time=   8.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=600, reg_alpha=0.1, reg_lambda=10, subsample=0.7; total time=   9.0s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=  17.4s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=  18.2s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   4.0s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=6, n_estimators=300, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   2.0s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   4.8s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=6, n_estimators=300, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   3.1s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=6, n_estimators=300, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   3.9s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=  14.0s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   6.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=6, n_estimators=300, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   4.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=6, n_estimators=300, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   4.7s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=  22.5s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=  14.0s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=  26.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=  12.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=  20.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=  33.5s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=  24.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=  36.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=  18.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=  27.5s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=  29.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=  20.8s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=  23.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=  18.4s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=  10.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=  24.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=  23.0s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   6.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   9.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=  26.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   0.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=  21.2s
# ...
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=1.0; total time=  10.7s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   4.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  24.1s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   4.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   5.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=1.0; total time=  11.0s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=  43.7s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  26.0s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   7.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=300, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=   5.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   8.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=300, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=   7.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   9.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=300, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=   8.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=  10.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=300, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=   9.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=300, reg_alpha=0, reg_lambda=5, subsample=1.0; total time=  10.4s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time=  55.9s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.01, max_depth=8, n_estimators=300, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=   7.5s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.9; total time= 1.0min
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.01, max_depth=8, n_estimators=300, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=   9.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=4, n_estimators=300, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=4, n_estimators=300, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.01, max_depth=8, n_estimators=300, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=  10.7s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=4, n_estimators=300, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=4, n_estimators=300, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=4, n_estimators=300, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.01, max_depth=8, n_estimators=300, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=  11.3s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.01, max_depth=8, n_estimators=300, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=  12.0s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=   6.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=  27.6s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=  23.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=  26.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=  25.7s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=  31.8s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   2.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=  33.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.7; total time=  58.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=  31.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   3.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   6.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   6.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   7.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=  23.6s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.7; total time= 1.2min
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=  26.3s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=  17.1s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.7; total time= 1.3min
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=  27.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=  10.6s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=  19.7s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=10, n_estimators=1000, reg_alpha=0, reg_lambda=5, subsample=0.7; total time= 1.4min
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=  22.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=  14.9s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=   6.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=  24.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   3.0s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=   8.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.05, max_depth=8, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=  26.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=   9.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   3.6s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=  17.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   4.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   5.0s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  10.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=6, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=  11.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   5.9s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=  21.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=300, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=  22.7s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=300, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=300, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=300, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=0.1, reg_lambda=5, subsample=0.9; total time=   9.6s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=300, reg_alpha=0.1, reg_lambda=5, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=0.1, reg_lambda=5, subsample=0.9; total time=  12.4s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=0.1, reg_lambda=5, subsample=0.9; total time=  13.7s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=0.1, reg_lambda=5, subsample=0.9; total time=  15.5s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=  10.3s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=600, reg_alpha=0.1, reg_lambda=5, subsample=0.9; total time=  16.8s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=   6.3s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=  18.8s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=10, subsample=0.9; total time=  17.6s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=  27.6s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=  12.4s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=  30.2s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   1.0s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   1.1s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=10, subsample=0.9; total time=  27.9s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=8, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=  31.4s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=  15.2s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=4, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   1.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=  17.9s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=10, subsample=0.9; total time=  31.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=  15.5s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=10, subsample=0.9; total time=  37.2s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=10, n_estimators=600, reg_alpha=0, reg_lambda=10, subsample=0.9; total time=  39.2s
# Best Parameters:
# {'subsample': 1.0, 'reg_lambda': 5, 'reg_alpha': 0.1, 'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.01, 'gamma': 0, 'colsample_bytree': 0.7}
#
# Best MAE:
# 27.54376214574966

# %%
# ---------------------------
# Data
# ---------------------------
df = data_12m.copy()
df = df.sort_values("DateTime(UTC)")

X = df.drop(columns=["Price[Currency/MWh]", "DateTime(UTC)"])
y = df["Price[Currency/MWh]"]

# ---------------------------
# Time series CV
# ---------------------------
tscv = TimeSeriesSplit(n_splits=5)

mae_scorer = make_scorer(mean_absolute_error, greater_is_better=False)

# ---------------------------
# Model (fixed regularization)
# ---------------------------
xgb = XGBRegressor(
    objective="reg:squarederror",
    tree_method="hist",
    random_state=42
)

# ---------------------------
# Focused parameter grid (HIGH IMPACT ONLY)
# ---------------------------

param_grid = {
    # tree complexity (VERY important)
    "max_depth": [4, 5, 6, 7],

    # learning dynamics (MOST important)
    "learning_rate": [0.005, 0.01, 0.02, 0.05],

    # boosting rounds
    "n_estimators": [300, 500, 800],

    # noise robustness (critical for electricity prices)
    "subsample": [0.7, 0.85, 1.0],

    # feature randomness (important due to many lag features)
    "colsample_bytree": [0.6, 0.75, 0.9]
}

# ---------------------------
# Grid search
# ---------------------------
grid_search = GridSearchCV(
    estimator=xgb,
    param_grid=param_grid,
    scoring=mae_scorer,
    cv=tscv,
    verbose=2,
    n_jobs=-1
)

grid_search.fit(X, y)

# ---------------------------
# Results
# ---------------------------
print("Best parameters:")
print(grid_search.best_params_)

print("\nBest MAE:")
print(-grid_search.best_score_)

# %% [markdown]
# ## Fit and display results

# %%
X.head()
# Out:
#        other  other_renewable    stable  variable  WTI_Oil  Brent_Oil  \
# 1628  163.85           102.84  30984.64   9262.71    72.84      77.11
# 1629  163.86           102.79  31155.75   9179.45    72.84      77.11
# 1630  163.88           102.68  31280.70   9130.39    72.84      77.11
# 1631  163.89           102.15  30708.83   8978.66    72.84      77.11
# 1632  163.85           101.68  30197.70   8865.19    72.84      77.11
#
#       Natural_Gas       load  temperature_c  humidity_percent  ...  \
# 1628         2.93  49590.034          1.475             85.25  ...
# 1629         2.93  49284.771          1.475             85.25  ...
# 1630         2.93  48936.994          1.475             85.25  ...
# 1631         2.93  48774.808          1.475             85.25  ...
# 1632         2.93  48611.645          0.925             88.00  ...
#
#       gas_lag_672  wti_lag_1344  brent_lag_1344  gas_lag_1344 is_holiday_288  \
# 1628         3.84         78.56           83.02          9.86            0.0
# 1629         3.84         78.56           83.02          9.86            0.0
# 1630         3.84         78.56           83.02          9.86            0.0
# 1631         3.84         78.56           83.02          9.86            0.0
# 1632         3.84         78.56           83.02          9.86            0.0
#
#       is_bridge_day_288  temperature_c_288  humidity_percent_288  \
# 1628                0.0             -1.875                 88.50
# 1629                0.0             -1.875                 88.50
# 1630                0.0             -1.875                 88.50
# 1631                0.0             -1.875                 88.50
# 1632                0.0             -2.075                 89.75
#
#       cloud_cover_percent_288  shortwave_radiation_wm2_288
# 1628                    59.25                          0.0
# 1629                    59.25                          0.0
# 1630                    59.25                          0.0
# 1631                    59.25                          0.0
# 1632                    53.25                          0.0
#
# [5 rows x 75 columns]

# %%
# ---------------------------
# 2. Define target + features
# ---------------------------

# Define target (3 days ahead = 288 steps)
target = 'target_288'

# Drop non-feature columns
drop_cols = ['DateTime(UTC)',
             'Price[Currency/MWh]',
             target,
             'date']
X = data_12m.drop(columns=drop_cols)
y = data_12m[target]

# ---------------------------
# 3. Train / Test split
# ---------------------------

# Last 3 days = 288 timesteps
forecast_horizon = 288

X_train = X.iloc[:-forecast_horizon]
y_train = y.iloc[:-forecast_horizon]

X_test = X.iloc[-forecast_horizon:]
y_test = y.iloc[-forecast_horizon:]

# ---------------------------
# 4. Train final model
# ---------------------------

best_params = random_search.best_params_

model = XGBRegressor(
    objective="reg:squarederror",
    tree_method="hist",
    random_state=42,
    **best_params
)

model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=300,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(X_test)

# %%
results = pd.DataFrame({
    "DateTime": data_12m['DateTime(UTC)'].iloc[-forecast_horizon:],
    "Actual_Price": data_12m['Price[Currency/MWh]'].iloc[-forecast_horizon:],
    "Predicted_Price": y_pred
})
results["DateTime_shifted"] = results["DateTime"] - pd.Timedelta(days=3)

# %%
# ---------------------------
# Compute MAE
# ---------------------------

mae = mean_absolute_error(results["Actual_Price"], results["Predicted_Price"])

# ---------------------------
# 7. Plot last 20 days
# ---------------------------

# 20 days = 20 * 96 timesteps
plot_horizon = 20 * 96

plot_data = data_12m.iloc[-plot_horizon:].copy()

plt.figure(figsize=(16, 6))

# Actual prices
plt.plot(
    plot_data['DateTime(UTC)'],
    plot_data['Price[Currency/MWh]'],
    label='Actual Price',
    linewidth=2
)

# Predictions (only last 3 days)
plt.plot(
    results['DateTime'],
    results['Predicted_Price'],
    label='Predictions (3 days ahead)',
    linestyle='--',
    linewidth=2
)

# Predictions (shifted)
# plt.plot(
#     results['DateTime_shifted'],
#     results['Predicted_Price'],
#     label='Predictions (made 3 days earlier)',
#     linestyle='--',
#     linewidth=2
# )

plt.title(f'Energy Price Forecast (Last 20 Days) | MAE (3-day forecast): {mae:.2f}')
plt.xlabel('Date')
plt.ylabel('Price [Currency/MWh]')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
